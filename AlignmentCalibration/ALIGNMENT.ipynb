# %%
import ROOT
import math
import array
import os

# %%
def TriangleFunction(x, par):
    height, shift = par[0], par[1]
    x_value = x[0] - shift
    if abs(x_value) > 17.0:
        return 0.0
    else: 
        height * (17.0 - abs(x_value))

# %%
def MyFit(h2BaseLpos, h1BaseReturn, ModTitle, i=-1):
    c2 = ROOT.TCanvas("dummy", "dummy")
    c2.cd()

    NumberLposBins = h2BaseLpos.GetYaxis().GetNbins()
    NumberRotationPoints = 6
    NumberRotationBins = NumberLposBins // NumberRotationPoints

    H1Name = ""
    F1Name = ""
    if i >= 0 and i < NumberRotationPoints:
        H1Name = '{}_rot{}'.format(ModTitle, i)
        F1Name = '{}_fit_rot{}'.format(ModTitle, i)
        minbin = i * NumberRotationBins
        maxbin = minbin + NumberRotationBins
        h1Base = h2BaseLpos.ProjectionX(H1Name, minbin, maxbin)
        print(F1Name, i)
    else:
        H1Name = '{}_shift'.format(ModTitle)
        F1Name = '{}_fit'.format(ModTitle)
        h1Base = h2BaseLpos.ProjectionX(H1Name)
        print(F1Name, i)

    h1Base.Scale(1.0 / NumberLposBins)
    h1Base.SetName(H1Name)
    h1Base.SetTitle(H1Name)
    h1Base.GetYaxis().SetTitle("Energy (MeV)")

    f1 = ROOT.TF1(F1Name, TriangleFunction, -17.0, +17.0, 2)
    f1.SetParameter(0, 3.5)
    f1.SetParameter(1, 0.0)
    
    h1Base.Fit(F1Name, "Q", "Q")
    shift = f1.GetParameter(1)
    h1Base.Fit(F1Name, "Q", "Q", shift - 10.0, shift + 10.0)
    shift = f1.GetParameter(1)

    if h1BaseReturn != 0:
        h1BaseReturn = h1Base

    return shift

# %%
def DoAlignment():
    fptext = open("AlignmentConstants.txt", "w")

    fin = ROOT.TFile("ReadNT.root")
    moduleLposBase = fin.Get("moduleLposBase")
    
    moduleLposBase.GetYaxis().SetTitle("lpos")
    moduleLposBase.GetZaxis().SetTitle("triangle base")
    
    c1 = ROOT.TCanvas("c1", "c1")
    c1.Divide(2, 2)
    c1.Print("AlignmentBook.pdf[")

    for modbin in range(1, 241):
        module_number = moduleLposBase.GetXaxis().GetBinLowEdge(modbin)
        module = int(5 + module_number) - 5
        plane = int(2 * (module_number + 5)) % 2 + 1

        print("Doing alignment for module", module, "plane", plane)

        if plane == 1:
            c1.Clear("D")

        ModTitle = ""
        if module >= 0:
            ModTitle = "mod{:03d}pl{:1d}".format(module, plane)
        if module < 0:
            ModTitle = "modm{:1d}pl{:1d}".format(module, plane)

        moduleLposBase.GetXaxis().SetRange(modbin, modbin)

        H2Name = "{}_2D".format(ModTitle)
        h2BaseLpos = moduleLposBase.Project3D("yz")
        h2BaseLpos.SetName(H2Name)
        h2BaseLpos.SetTitle("Module {} Plane {};Base Position (mm);Longitudinal Position (mm);Average Energy (MeV)".format(module, plane))

        if h2BaseLpos.GetEntries() == 0:
            continue

        h1Base = ROOT.TH1D()
        shift = -MyFit(h2BaseLpos, h1Base, ModTitle)

        lpos_point = array.array('d', [-1200.0 + 400.0 * i + 200.0 for i in range(6)])
        shift_point = array.array('d', [MyFit(h2BaseLpos, 0, ModTitle, i) for i in range(6)])
        
        tgrRotation = ROOT.TGraph(6, shift_point, lpos_point)
        tgrFit = ROOT.TGraph(6, lpos_point, shift_point)
        tgrFit.Fit("pol1", "Q", "Q")
        LowPoint = tgrFit.GetFunction("pol1").Eval(-1000.0)
        HighPoint = tgrFit.GetFunction("pol1").Eval(1000.0)
        rotation = 1000 * math.atan((HighPoint - LowPoint) / 2000.0)

        c1.cd(2 * (plane - 1) + 1)
        h2BaseLpos.SetMaximum(4)
        h2BaseLpos.Draw("colz")
        tgrRotation.SetMarkerStyle(ROOT.kOpenCircle)
        tgrRotation.Draw("P same")
        tline = ROOT.TLine(LowPoint, -1000.0, HighPoint, 1000.0)
        tline.SetLineWidth(3)
        tline.Draw("same")
        c1.cd(2 * (plane - 1) + 2)
        h1Base.SetMaximum(4)
        h1Base.SetTitle("Module {} Plane {};Base Position (mm);Average Energy (MeV)".format(module, plane))
        h1Base.Draw()
        ModString = "Module {} Plane {}".format(module, plane)
        ShiftString = "Shift = {:+5.3f} mm".format(shift)
        RotationString = "Rotation = {:+5.3f} mrad\n".format(rotation)
        ModLabel = ROOT.TPaveLabel(5.0, 4.00, 17.0, 3.75, ModString)
        ShiftLabel = ROOT.TPaveLabel(5.0, 3.75, 17.0, 3.50, ShiftString)
        RotationLabel = ROOT.TPaveLabel(5.0, 3.50, 17.0, 3.25, RotationString)
        ModLabel.Draw()
        ShiftLabel.Draw()
        RotationLabel.Draw()
        if plane == 2:
            c1.Print("AlignmentBook.pdf")

        c2 = ROOT.TCanvas("c2", "c2", 800, 500)
        c2.Divide(2, 1)
        c2.cd(1)
        h1Base.Draw()
        c2.cd(2)
        h2BaseLpos.Draw("colz")
        tgrRotation.Draw("P same")
        tline.Draw("same")
        c2.Print("alignmentPlotDump/mod{:03d}pl{}.png".format(module, plane))
        del c2

        fptext.write("module: {} plane: {} shift: {} rotation: {}\n".format(module, plane, shift, rotation))

    c1.Print("AlignmentBook.pdf]")
    fptext.close()

# %%
DoAlignment()
# Out:
# Doing alignment for module -5 plane 1
# Doing alignment for module -5 plane 2
# Doing alignment for module -4 plane 1
# Doing alignment for module -4 plane 2
# Doing alignment for module -3 plane 1
# Doing alignment for module -3 plane 2
# Doing alignment for module -2 plane 1
# Doing alignment for module -2 plane 2
# Doing alignment for module -1 plane 1
# Doing alignment for module -1 plane 2
# Doing alignment for module 0 plane 1
# Doing alignment for module 0 plane 2
# Doing alignment for module 1 plane 1
# mod001pl1_fit -1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/fermi/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments/DUNE/💻 DUNE_Notebooks/AlignmentCalibration/ALIGNMENT.ipynb Cell 5 line 1
# ----> <a href='vscode-notebook-cell:/Users/fermi/Library/CloudStorage/GoogleDrive-rvizarreta14%40gmail.com/My%20Drive/%F0%9F%8F%9B%20PhD%20Repository/%F0%9F%9A%80%20Research/%F0%9F%A4%96%20Experiments/DUNE/%F0%9F%92%BB%20DUNE_Notebooks/AlignmentCalibration/ALIGNMENT.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> DoAlignment()
#
# /Users/fermi/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments/DUNE/💻 DUNE_Notebooks/AlignmentCalibration/ALIGNMENT.ipynb Cell 5 line 4
#      <a href='vscode-notebook-cell:/Users/fermi/Library/CloudStorage/GoogleDrive-rvizarreta14%40gmail.com/My%20Drive/%F0%9F%8F%9B%20PhD%20Repository/%F0%9F%9A%80%20Research/%F0%9F%A4%96%20Experiments/DUNE/%F0%9F%92%BB%20DUNE_Notebooks/AlignmentCalibration/ALIGNMENT.ipynb#W4sZmlsZQ%3D%3D?line=37'>38</a>     continue
#      <a href='vscode-notebook-cell:/Users/fermi/Library/CloudStorage/GoogleDrive-rvizarreta14%40gmail.com/My%20Drive/%F0%9F%8F%9B%20PhD%20Repository/%F0%9F%9A%80%20Research/%F0%9F%A4%96%20Experiments/DUNE/%F0%9F%92%BB%20DUNE_Notebooks/AlignmentCalibration/ALIGNMENT.ipynb#W4sZmlsZQ%3D%3D?line=39'>40</a> h1Base = ROOT.TH1D()
# ---> <a href='vscode-notebook-cell:/Users/fermi/Library/CloudStorage/GoogleDrive-rvizarreta14%40gmail.com/My%20Drive/%F0%9F%8F%9B%20PhD%20Repository/%F0%9F%9A%80%20Research/%F0%9F%A4%96%20Experiments/DUNE/%F0%9F%92%BB%20DUNE_Notebooks/AlignmentCalibration/ALIGNMENT.ipynb#W4sZmlsZQ%3D%3D?line=40'>41</a> shift = -MyFit(h2BaseLpos, h1Base, ModTitle)
#      <a href='vscode-notebook-cell:/Users/fermi/Library/CloudStorage/GoogleDrive-rvizarreta14%40gmail.com/My%20Drive/%F0%9F%8F%9B%20PhD%20Repository/%F0%9F%9A%80%20Research/%F0%9F%A4%96%20Experiments/DUNE/%F0%9F%92%BB%20DUNE_Notebooks/AlignmentCalibration/ALIGNMENT.ipynb#W4sZmlsZQ%3D%3D?line=42'>43</a> lpos_point = array.array('d', [-1200.0 + 400.0 * i + 200.0 for i in range(6)])
#      <a href='vscode-notebook-cell:/Users/fermi/Library/CloudStorage/GoogleDrive-rvizarreta14%40gmail.com/My%20Drive/%F0%9F%8F%9B%20PhD%20Repository/%F0%9F%9A%80%20Research/%F0%9F%A4%96%20Experiments/DUNE/%F0%9F%92%BB%20DUNE_Notebooks/AlignmentCalibration/ALIGNMENT.ipynb#W4sZmlsZQ%3D%3D?line=43'>44</a> shift_point = array.array('d', [MyFit(h2BaseLpos, 0, ModTitle, i) for i in range(6)])
#
# /Users/fermi/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments/DUNE/💻 DUNE_Notebooks/AlignmentCalibration/ALIGNMENT.ipynb Cell 5 line 3
#      <a href='vscode-notebook-cell:/Users/fermi/Library/CloudStorage/GoogleDrive-rvizarreta14%40gmail.com/My%20Drive/%F0%9F%8F%9B%20PhD%20Repository/%F0%9F%9A%80%20Research/%F0%9F%A4%96%20Experiments/DUNE/%F0%9F%92%BB%20DUNE_Notebooks/AlignmentCalibration/ALIGNMENT.ipynb#W4sZmlsZQ%3D%3D?line=29'>30</a> f1.SetParameter(0, 3.5)
#      <a href='vscode-notebook-cell:/Users/fermi/Library/CloudStorage/GoogleDrive-rvizarreta14%40gmail.com/My%20Drive/%F0%9F%8F%9B%20PhD%20Repository/%F0%9F%9A%80%20Research/%F0%9F%A4%96%20Experiments/DUNE/%F0%9F%92%BB%20DUNE_Notebooks/AlignmentCalibration/ALIGNMENT.ipynb#W4sZmlsZQ%3D%3D?line=30'>31</a> f1.SetParameter(1, 0.0)
# ---> <a href='vscode-notebook-cell:/Users/fermi/Library/CloudStorage/GoogleDrive-rvizarreta14%40gmail.com/My%20Drive/%F0%9F%8F%9B%20PhD%20Repository/%F0%9F%9A%80%20Research/%F0%9F%A4%96%20Experiments/DUNE/%F0%9F%92%BB%20DUNE_Notebooks/AlignmentCalibration/ALIGNMENT.ipynb#W4sZmlsZQ%3D%3D?line=32'>33</a> h1Base.Fit(F1Name, "Q", "Q")
#      <a href='vscode-notebook-cell:/Users/fermi/Library/CloudStorage/GoogleDrive-rvizarreta14%40gmail.com/My%20Drive/%F0%9F%8F%9B%20PhD%20Repository/%F0%9F%9A%80%20Research/%F0%9F%A4%96%20Experiments/DUNE/%F0%9F%92%BB%20DUNE_Notebooks/AlignmentCalibration/ALIGNMENT.ipynb#W4sZmlsZQ%3D%3D?line=33'>34</a> shift = f1.GetParameter(1)
#      <a href='vscode-notebook-cell:/Users/fermi/Library/CloudStorage/GoogleDrive-rvizarreta14%40gmail.com/My%20Drive/%F0%9F%8F%9B%20PhD%20Repository/%F0%9F%9A%80%20Research/%F0%9F%A4%96%20Experiments/DUNE/%F0%9F%92%BB%20DUNE_Notebooks/AlignmentCalibration/ALIGNMENT.ipynb#W4sZmlsZQ%3D%3D?line=34'>35</a> h1Base.Fit(F1Name, "Q", "Q", shift - 10.0, shift + 10.0)
#
# TypeError: none of the 2 overloaded methods succeeded. Full details:
#   TFitResultPtr TH1::Fit(TF1* f1, const char* option = "", const char* goption = "", double xmin = 0, double xmax = 0) =>
#     TypeError: could not convert argument 1
#   TFitResultPtr TH1::Fit(const char* formula, const char* option = "", const char* goption = "", double xmin = 0, double xmax = 0) =>
#     AbortSignal: abort from C++; program state was reset
# [/Users/fermi/anaconda3/envs/pyroot/lib/libcppyy_backend3_11.6.28.04.so] (anonymous namespace)::TExceptionHandlerImp::HandleException(int) (no debug info)
# [/Users/fermi/anaconda3/envs/pyroot/lib/libCore.6.28.04.so] TUnixSystem::DispatchSignals(ESignals) (no debug info)
# [/usr/lib/system/libsystem_platform.dylib] _sigtramp (no debug info)
# [/usr/lib/system/libsystem_pthread.dylib] pthread_kill (no debug info)
# [/usr/lib/system/libsystem_c.dylib] abort (no debug info)
# [/usr/lib/libc++abi.dylib] __cxxabiv1::__aligned_malloc_with_fallback(unsigned long) (no debug info)
# [/usr/lib/libc++abi.dylib] demangling_terminate_handler() (no debug info)
# [/usr/lib/libobjc.A.dylib] _objc_terminate() (no debug info)
# [/usr/lib/libc++abi.dylib] std::__terminate(void (*)()) (no debug info)
# [/usr/lib/libc++abi.dylib] __cxa_get_exception_ptr (no debug info)
# [/usr/lib/libc++abi.dylib] __cxxabiv1::exception_cleanup_func(_Unwind_Reason_Code, _Unwind_Exception*) (no debug info)
# [<unknown binary>] (no debug info)
# [/Users/fermi/anaconda3/envs/pyroot/lib/libHist.6.28.04.so] TF1::EvalPar(double const*, double const*) (no debug info)
# [/Users/fermi/anaconda3/envs/pyroot/lib/libHist.6.28.04.so] ROOT::Fit::FillData(ROOT::Fit::BinData&, TH1 const*, TF1*) (no debug info)
# [/Users/fermi/anaconda3/envs/pyroot/lib/libHist.6.28.04.so] TFitResultPtr HFit::Fit<TH1>(TH1*, TF1*, Foption_t&, ROOT::Math::MinimizerOptions const&, char const*, ROOT::Fit::DataRange&) (no debug info)
# [/Users/fermi/anaconda3/envs/pyroot/lib/libHist.6.28.04.so] TH1::Fit(TF1*, char const*, char const*, double, double) (no debug info)
# [<unknown binary>] (no debug info)
# [/Users/fermi/anaconda3/envs/pyroot/lib/libcppyy_backend3_11.6.28.04.so] WrapperCall(long, unsigned long, void*, void*, void*) (no debug info)
# [/Users/fermi/anaconda3/envs/pyroot/lib/libcppyy_backend3_11.6.28.04.so] Cppyy::CallO(long, void*, unsigned long, void*, unsigned long) (no debug info)
# [/Users/fermi/anaconda3/envs/pyroot/lib/libcppyy3_11.6.28.04.so] CPyCppyy::(anonymous namespace)::InstanceExecutor::Execute(long, void*, CPyCppyy::CallContext*) (no debug info)
# [/Users/fermi/anaconda3/envs/pyroot/lib/libcppyy3_11.6.28.04.so] CPyCppyy::CPPMethod::ExecuteFast(void*, long, CPyCppyy::CallContext*) (no debug info)
# [/Users/fermi/anaconda3/envs/pyroot/lib/libcppyy3_11.6.28.04.so] CPyCppyy::CPPMethod::ExecuteProtected(void*, long, CPyCppyy::CallContext*) (no debug info)
# [/Users/fermi/anaconda3/envs/pyroot/lib/libcppyy3_11.6.28.04.so] CPyCppyy::CPPMethod::Call(CPyCppyy::CPPInstance*&, _object*, _object*, CPyCppyy::CallContext*) (no debug info)
# [/Users/fermi/anaconda3/envs/pyroot/lib/libcppyy3_11.6.28.04.so] CPyCppyy::(anonymous namespace)::mp_call(CPyCppyy::CPPOverload*, _object*, _object*) (no debug info)
# [/Users/fermi/anaconda3/envs/pyroot/bin/python3.11] _PyObject_MakeTpCall (no debug info)
# [/Users/fermi/anaconda3/envs/pyroot/bin/python3.11] _PyEval_EvalFrameDefault (no debug info)
# [/Users/fermi/anaconda3/envs/pyroot/bin/python3.11] PyEval_EvalCode (no debug info)
# [/Users/fermi/anaconda3/envs/pyroot/bin/python3.11] builtin_exec (no debug info)
# [/Users/fermi/anaconda3/envs/pyroot/bin/python3.11] _PyEval_EvalFrameDefault (no debug info)
# [/Users/fermi/anaconda3/envs/pyroot/bin/python3.11] gen_send_ex2 (no debug info)
# [/Users/fermi/anaconda3/envs/pyroot/bin/python3.11] _PyEval_EvalFrameDefault (no debug info)
# [/Users/fermi/anaconda3/envs/pyroot/bin/python3.11] gen_send_ex2 (no debug info)
# [/Users/fermi/anaconda3/envs/pyroot/bin/python3.11] _PyEval_EvalFrameDefault (no debug info)
# [/Users/fermi/anaconda3/envs/pyroot/bin/python3.11] gen_send_ex2 (no debug info)
# [/Users/fermi/anaconda3/envs/pyroot/bin/python3.11] gen_send_ex (no debug info)
# [/Users/fermi/anaconda3/envs/pyroot/bin/python3.11] _PyEval_EvalFrameDefault (no debug info)
# [/Users/fermi/anaconda3/envs/pyroot/bin/python3.11] _PyEval_Vector (no debug info)
# [/Users/fermi/anaconda3/envs/pyroot/bin/python3.11] method_vectorcall (no debug info)
# [/Users/fermi/anaconda3/envs/pyroot/bin/python3.11] _PyVectorcall_Call (no debug info)
# [/Users/fermi/anaconda3/envs/pyroot/bin/python3.11] _PyEval_EvalFrameDefault (no debug info)
# [/Users/fermi/anaconda3/envs/pyroot/bin/python3.11] gen_send_ex2 (no debug info)
# [/Users/fermi/anaconda3/envs/pyroot/bin/python3.11] _PyEval_EvalFrameDefault (no debug info)
# [/Users/fermi/anaconda3/envs/pyroot/bin/python3.11] gen_send_ex2 (no debug info)
# [/Users/fermi/anaconda3/envs/pyroot/bin/python3.11] _PyEval_EvalFrameDefault (no debug info)
# [/Users/fermi/anaconda3/envs/pyroot/bin/python3.11] gen_send_ex2 (no debug info)
# [/Users/fermi/anaconda3/envs/pyroot/bin/python3.11] _PyEval_EvalFrameDefault (no debug info)
# [/Users/fermi/anaconda3/envs/pyroot/bin/python3.11] gen_send_ex2 (no debug info)
# [/Users/fermi/anaconda3/envs/pyroot/bin/python3.11] _PyEval_EvalFrameDefault (no debug info)
# [/Users/fermi/anaconda3/envs/pyroot/bin/python3.11] gen_send_ex2 (no debug info)
# [/Users/fermi/anaconda3/envs/pyroot/lib/python3.11/lib-dynload/_asyncio.cpython-311-darwin.so] task_step (no debug info)
# [/Users/fermi/anaconda3/envs/pyroot/lib/python3.11/lib-dynload/_asyncio.cpython-311-darwin.so] task_wakeup (no debug info)
# [/Users/fermi/anaconda3/envs/pyroot/bin/python3.11] cfunction_vectorcall_O (no debug info)
# [/Users/fermi/anaconda3/envs/pyroot/bin/python3.11] context_run (no debug info)
# [/Users/fermi/anaconda3/envs/pyroot/bin/python3.11] cfunction_vectorcall_FASTCALL_KEYWORDS (no debug info)
# [/Users/fermi/anaconda3/envs/pyroot/bin/python3.11] _PyEval_EvalFrameDefault (no debug info)
# [/Users/fermi/anaconda3/envs/pyroot/bin/python3.11] PyEval_EvalCode (no debug info)
# [/Users/fermi/anaconda3/envs/pyroot/bin/python3.11] builtin_exec (no debug info)
# [/Users/fermi/anaconda3/envs/pyroot/bin/python3.11] cfunction_vectorcall_FASTCALL_KEYWORDS (no debug info)
# [/Users/fermi/anaconda3/envs/pyroot/bin/python3.11] PyObject_Vectorcall (no debug info)
# [/Users/fermi/anaconda3/envs/pyroot/bin/python3.11] _PyEval_EvalFrameDefault (no debug info)
# [/Users/fermi/anaconda3/envs/pyroot/bin/python3.11] _PyEval_Vector (no debug info)
# [/Users/fermi/anaconda3/envs/pyroot/bin/python3.11] pymain_run_module (no debug info)
# [/Users/fermi/anaconda3/envs/pyroot/bin/python3.11] Py_RunMain (no debug info)
# [/Users/fermi/anaconda3/envs/pyroot/bin/python3.11] pymain_main (no debug info)
# [/Users/fermi/anaconda3/envs/pyroot/bin/python3.11] main (no debug info)
# [/usr/lib/dyld] start (no debug info)
# Info in <TCanvas::Print>: pdf file AlignmentBook.pdf has been created
# libc++abi: terminating due to uncaught exception of type CPyCppyy::PyException: python exception
#  *** Break *** abort
