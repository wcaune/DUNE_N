# %%
import ROOT
# Out:
# Welcome to JupyROOT 6.28/04

# %%
fin = ROOT.TFile("ReadNT.root")
moduleLposBase = fin.Get("moduleLposBase")
canvas = ROOT.TCanvas("canvas", "Plot")
moduleLposBase.Draw("chisq")
canvas.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas

# %%
module_number = moduleLposBase.GetXaxis().GetBinLowEdge(1)
module = int(5 + module_number) - 5
plane = int(2 * (module_number + 5)) % 2 + 1
module, plane
# Out:
# (-5, 1)

# %%
h2BaseLpos = moduleLposBase.Project3D("yz")
canvas = ROOT.TCanvas("canvas", "Plot")
h2BaseLpos.Draw("chisq")
canvas.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas

# %%
h2BaseLpos = moduleLposBase.Project3D("xz")
canvas = ROOT.TCanvas("canvas", "Plot")
h2BaseLpos.Draw("chisq")
canvas.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas

# %%
h2BaseLpos = moduleLposBase.Project3D("xy")
canvas = ROOT.TCanvas("canvas", "Plot")
h2BaseLpos.Draw("chisq")
canvas.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas

# %%
h2BaseLpos.GetYaxis().GetNbins()
# Out:
# 24
