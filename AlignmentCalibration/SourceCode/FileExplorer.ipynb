# %%
'''
ROOT FILE EXPLORER FOR THE ALIGNMENT CALIBRATION
Author: Renzo Vizarreta
Notebook date: November 14th, 2023.
'''

# --- ROOT AND PLOTTING PACKAGES ---
# For instructions about downloading ROOT go to: https://root.cern/manual/python/
import ROOT
# For instructions about running the dunestyle go to: https://github.com/DUNE/dune_plot_style
import dunestyle.root as dunestyle
from ipywidgets import interact, widgets
# ----------------------------------
# Out:
# Welcome to JupyROOT 6.28/04
# DUNE plot style enabled

# %%
root_file = ROOT.TFile('../RESOURCES/DATA/pass1_11_01_2023/TS1_00040048_0001_numib_v09_2307062140_RockMuonCalib_tuple.root')
root_file.ls()
# Out:
# TFile**		../RESOURCES/DATA/pass1_11_01_2023/TS1_00040048_0001_numib_v09_2307062140_RockMuonCalib_tuple.root
#  TFile*		../RESOURCES/DATA/pass1_11_01_2023/TS1_00040048_0001_numib_v09_2307062140_RockMuonCalib_tuple.root
#   KEY: TTree	nt;4	nt [current cycle]
#   KEY: TTree	nt;3	nt [backup cycle]
#   KEY: TTree	header;1	header
#   KEY: TTree	gates;1	gates

# %%
root_file.Get("nt").Print()
# Out:
# ******************************************************************************
# *Tree    :nt        : nt                                                     *
# *Entries :     9396 : Total =       272794065 bytes  File  Size =  117594111 *
# *        :          : Tree compression factor =   2.32                       *
# ******************************************************************************
# *Br    0 :ev_run    : ev_run/I                                               *
# *Entries :     9396 : Total  Size=      38570 bytes  File Size  =        932 *
# *Baskets :        7 : Basket Size=       7103 bytes  Compression=  40.86     *
# *............................................................................*
# *Br    1 :ev_subrun : ev_subrun/I                                            *
# *Entries :     9396 : Total  Size=      38603 bytes  File Size  =        944 *
# *Baskets :        7 : Basket Size=       7103 bytes  Compression=  40.36     *
# *............................................................................*
# *Br    2 :ev_gate   : ev_gate/I                                              *
# *Entries :     9396 : Total  Size=      38581 bytes  File Size  =      11147 *
# *Baskets :        7 : Basket Size=       7103 bytes  Compression=   3.42     *
# *............................................................................*
# *Br    3 :ev_isMC   : ev_isMC/I                                              *
# *Entries :     9396 : Total  Size=      38581 bytes  File Size  =        887 *
# *Baskets :        7 : Basket Size=       7103 bytes  Compression=  42.94     *
# *............................................................................*
# *Br    4 :ev_ntracks : ev_ntracks/I                                          *
# *Entries :     9396 : Total  Size=      38614 bytes  File Size  =       2246 *
# *Baskets :        7 : Basket Size=       7103 bytes  Compression=  16.97     *
# *............................................................................*
# *Br    5 :ev_gps_time : ev_gps_time/l                                        *
# *Entries :     9396 : Total  Size=      76217 bytes  File Size  =      27157 *
# *Baskets :        7 : Basket Size=      11776 bytes  Compression=   2.79     *
# *............................................................................*
# *Br    6 :ev_timeslice : ev_timeslice/I                                      *
# *Entries :     9396 : Total  Size=      38636 bytes  File Size  =       9730 *
# *Baskets :        7 : Basket Size=       7103 bytes  Compression=   3.92     *
# *............................................................................*
# *Br    7 :ev_trktheta : ev_trktheta/D                                        *
# *Entries :     9396 : Total  Size=      75989 bytes  File Size  =      71746 *
# *Baskets :        4 : Basket Size=      23552 bytes  Compression=   1.05     *
# *............................................................................*
# *Br    8 :ev_trkAx  : ev_trkAx/D                                             *
# *Entries :     9396 : Total  Size=      75965 bytes  File Size  =      72602 *
# *Baskets :        4 : Basket Size=      23552 bytes  Compression=   1.04     *
# *............................................................................*
# *Br    9 :ev_trkAy  : ev_trkAy/D                                             *
# *Entries :     9396 : Total  Size=      75965 bytes  File Size  =      72456 *
# *Baskets :        4 : Basket Size=      23552 bytes  Compression=   1.04     *
# *............................................................................*
# *Br   10 :ev_trk_exit : ev_trk_exit[3]/D                                     *
# *Entries :     9396 : Total  Size=     226331 bytes  File Size  =     165314 *
# *Baskets :        4 : Basket Size=      70656 bytes  Compression=   1.37     *
# *............................................................................*
# *Br   11 :ev_trk    : ev_trk[3]/D                                            *
# *Entries :     9396 : Total  Size=     226291 bytes  File Size  =     166123 *
# *Baskets :        4 : Basket Size=      70656 bytes  Compression=   1.36     *
# *............................................................................*
# *Br   12 :ev_trk_exitAx : ev_trk_exitAx/D                                    *
# *Entries :     9396 : Total  Size=      76005 bytes  File Size  =      72615 *
# *Baskets :        4 : Basket Size=      23552 bytes  Compression=   1.04     *
# *............................................................................*
# *Br   13 :ev_trk_exitAy : ev_trk_exitAy/D                                    *
# *Entries :     9396 : Total  Size=      76005 bytes  File Size  =      72465 *
# *Baskets :        4 : Basket Size=      23552 bytes  Compression=   1.04     *
# *............................................................................*
# *Br   14 :ev_muonEnterFront : ev_muonEnterFront/I                            *
# *Entries :     9396 : Total  Size=      38691 bytes  File Size  =       4688 *
# *Baskets :        7 : Basket Size=       7103 bytes  Compression=   8.14     *
# *............................................................................*
# *Br   15 :ev_muonEnterSide : ev_muonEnterSide/I                              *
# *Entries :     9396 : Total  Size=      38680 bytes  File Size  =       4511 *
# *Baskets :        7 : Basket Size=       7103 bytes  Compression=   8.46     *
# *............................................................................*
# *Br   16 :ev_muonExitBack : ev_muonExitBack/I                                *
# *Entries :     9396 : Total  Size=      38669 bytes  File Size  =       4754 *
# *Baskets :        7 : Basket Size=       7103 bytes  Compression=   8.02     *
# *............................................................................*
# *Br   17 :ev_muonExitSide : ev_muonExitSide/I                                *
# *Entries :     9396 : Total  Size=      38669 bytes  File Size  =       4561 *
# *Baskets :        7 : Basket Size=       7103 bytes  Compression=   8.36     *
# *............................................................................*
# *Br   18 :ev_extraEnergy : ev_extraEnergy/D                                  *
# *Entries :     9396 : Total  Size=      76013 bytes  File Size  =      72004 *
# *Baskets :        4 : Basket Size=      23552 bytes  Compression=   1.05     *
# *............................................................................*
# *Br   19 :ev_minosMatch : ev_minosMatch/I                                    *
# *Entries :     9396 : Total  Size=      38647 bytes  File Size  =        929 *
# *Baskets :        7 : Basket Size=       7103 bytes  Compression=  41.04     *
# *............................................................................*
# *Br   20 :ev_MEU    : ev_MEU/D                                               *
# *Entries :     9396 : Total  Size=      75949 bytes  File Size  =        884 *
# *Baskets :        4 : Basket Size=      23552 bytes  Compression=  85.35     *
# *............................................................................*
# *Br   21 :ev_LY     : ev_LY/D                                                *
# *Entries :     9396 : Total  Size=      75941 bytes  File Size  =        736 *
# *Baskets :        4 : Basket Size=      23552 bytes  Compression= 102.51     *
# *............................................................................*
# *Br   22 :ev_minosTrackQuality : ev_minosTrackQuality/I                      *
# *Entries :     9396 : Total  Size=      38724 bytes  File Size  =        978 *
# *Baskets :        7 : Basket Size=       7103 bytes  Compression=  39.04     *
# *............................................................................*
# *Br   23 :ev_minosTrackChi2 : ev_minosTrackChi2/D                            *
# *Entries :     9396 : Total  Size=      76037 bytes  File Size  =        912 *
# *Baskets :        4 : Basket Size=      23552 bytes  Compression=  82.78     *
# *............................................................................*
# *Br   24 :ev_minosTrackNDF : ev_minosTrackNDF/D                              *
# *Entries :     9396 : Total  Size=      76029 bytes  File Size  =        908 *
# *Baskets :        4 : Basket Size=      23552 bytes  Compression=  83.14     *
# *............................................................................*
# *Br   25 :ev_minosTrackPassFit : ev_minosTrackPassFit/D                      *
# *Entries :     9396 : Total  Size=      76061 bytes  File Size  =        924 *
# *Baskets :        4 : Basket Size=      23552 bytes  Compression=  81.72     *
# *............................................................................*
# *Br   26 :ev_minosRecoByRange : ev_minosRecoByRange/I                        *
# *Entries :     9396 : Total  Size=      38713 bytes  File Size  =        971 *
# *Baskets :        7 : Basket Size=       7103 bytes  Compression=  39.31     *
# *............................................................................*
# *Br   27 :ev_minosRecoByCurvature : ev_minosRecoByCurvature/I                *
# *Entries :     9396 : Total  Size=      38757 bytes  File Size  =        999 *
# *Baskets :        7 : Basket Size=       7103 bytes  Compression=  38.24     *
# *............................................................................*
# *Br   28 :ev_minosP : ev_minosP/D                                            *
# *Entries :     9396 : Total  Size=      75973 bytes  File Size  =        880 *
# *Baskets :        4 : Basket Size=      23552 bytes  Compression=  85.75     *
# *............................................................................*
# *Br   29 :ev_minosPrange : ev_minosPrange/D                                  *
# *Entries :     9396 : Total  Size=      76013 bytes  File Size  =        900 *
# *Baskets :        4 : Basket Size=      23552 bytes  Compression=  83.87     *
# *............................................................................*
# *Br   30 :ev_minosPcurve : ev_minosPcurve/D                                  *
# *Entries :     9396 : Total  Size=      76013 bytes  File Size  =        900 *
# *Baskets :        4 : Basket Size=      23552 bytes  Compression=  83.87     *
# *............................................................................*
# *Br   31 :ev_muonCharge : ev_muonCharge/D                                    *
# *Entries :     9396 : Total  Size=      76005 bytes  File Size  =        768 *
# *Baskets :        4 : Basket Size=      23552 bytes  Compression=  98.28     *
# *............................................................................*
# *Br   32 :ev_minosVtx : ev_minosVtx[3]/D                                     *
# *Entries :     9396 : Total  Size=     226331 bytes  File Size  =       1676 *
# *Baskets :        4 : Basket Size=      70656 bytes  Compression= 134.73     *
# *............................................................................*
# *Br   33 :ev_muonVtx : ev_muonVtx[3]/D                                       *
# *Entries :     9396 : Total  Size=     226323 bytes  File Size  =       1672 *
# *Baskets :        4 : Basket Size=      70656 bytes  Compression= 135.05     *
# *............................................................................*
# *Br   34 :ev_muonP  : ev_muonP[3]/D                                          *
# *Entries :     9396 : Total  Size=     226307 bytes  File Size  =       1664 *
# *Baskets :        4 : Basket Size=      70656 bytes  Compression= 135.69     *
# *............................................................................*
# *Br   35 :ev_muonE  : ev_muonE/D                                             *
# *Entries :     9396 : Total  Size=      75965 bytes  File Size  =        864 *
# *Baskets :        4 : Basket Size=      23552 bytes  Compression=  87.34     *
# *............................................................................*
# *Br   36 :ev_minosMatchDeltaT : ev_minosMatchDeltaT/D                        *
# *Entries :     9396 : Total  Size=      76053 bytes  File Size  =        908 *
# *Baskets :        4 : Basket Size=      23552 bytes  Compression=  83.15     *
# *............................................................................*
# *Br   37 :ev_minosTrackQP : ev_minosTrackQP/D                                *
# *Entries :     9396 : Total  Size=      76021 bytes  File Size  =        892 *
# *Baskets :        4 : Basket Size=      23552 bytes  Compression=  84.63     *
# *............................................................................*
# *Br   38 :ev_minosTrackSigmaQP : ev_minosTrackSigmaQP/D                      *
# *Entries :     9396 : Total  Size=      76061 bytes  File Size  =        912 *
# *Baskets :        4 : Basket Size=      23552 bytes  Compression=  82.79     *
# *............................................................................*
# *Br   39 :ev_muonTruePDG : ev_muonTruePDG/I                                  *
# *Entries :     9396 : Total  Size=      38658 bytes  File Size  =        936 *
# *Baskets :        7 : Basket Size=       7103 bytes  Compression=  40.74     *
# *............................................................................*
# *Br   40 :ev_muonTrueVtx : ev_muonTrueVtx[3]/D                               *
# *Entries :     9396 : Total  Size=     226355 bytes  File Size  =       1430 *
# *Baskets :        4 : Basket Size=      70656 bytes  Compression= 157.92     *
# *............................................................................*
# *Br   41 :ev_muonTrueP : ev_muonTrueP[3]/D                                   *
# *Entries :     9396 : Total  Size=     226339 bytes  File Size  =       1422 *
# *Baskets :        4 : Basket Size=      70656 bytes  Compression= 158.80     *
# *............................................................................*
# *Br   42 :ev_muonTrueE : ev_muonTrueE/D                                      *
# *Entries :     9396 : Total  Size=      75997 bytes  File Size  =        764 *
# *Baskets :        4 : Basket Size=      23552 bytes  Compression=  98.79     *
# *............................................................................*
# *Br   43 :n_entries : n_entries/I                                            *
# *Entries :     9396 : Total  Size=      38603 bytes  File Size  =      16473 *
# *Baskets :        7 : Basket Size=       7103 bytes  Compression=   2.31     *
# *............................................................................*
# *Br   44 :st_module : st_module[n_entries]/I                                 *
# *Entries :     9396 : Total  Size=    5842479 bytes  File Size  =     818890 *
# *Baskets :       53 : Basket Size=     910336 bytes  Compression=   7.13     *
# *............................................................................*
# *Br   45 :st_plane  : st_plane[n_entries]/I                                  *
# *Entries :     9396 : Total  Size=    5842422 bytes  File Size  =     315228 *
# *Baskets :       53 : Basket Size=     910336 bytes  Compression=  18.53     *
# *............................................................................*
# *Br   46 :st_strip  : st_strip[n_entries]/I                                  *
# *Entries :     9396 : Total  Size=    5842422 bytes  File Size  =    1556657 *
# *Baskets :       53 : Basket Size=     910336 bytes  Compression=   3.75     *
# *............................................................................*
# *Br   47 :st_rack   : st_rack[n_entries]/I                                   *
# *Entries :     9396 : Total  Size=    5842365 bytes  File Size  =     495849 *
# *Baskets :       53 : Basket Size=     910336 bytes  Compression=  11.78     *
# *............................................................................*
# *Br   48 :st_view   : st_view[n_entries]/I                                   *
# *Entries :     9396 : Total  Size=    5842365 bytes  File Size  =     390122 *
# *Baskets :       53 : Basket Size=     910336 bytes  Compression=  14.97     *
# *............................................................................*
# *Br   49 :st_mev    : st_mev[n_entries]/D                                    *
# *Entries :     9396 : Total  Size=   11641094 bytes  File Size  =    9687961 *
# *Baskets :       50 : Basket Size=    3551744 bytes  Compression=   1.20     *
# *............................................................................*
# *Br   50 :st_path   : st_path[n_entries]/D                                   *
# *Entries :     9396 : Total  Size=   11641148 bytes  File Size  =    7637387 *
# *Baskets :       50 : Basket Size=    3551744 bytes  Compression=   1.52     *
# *............................................................................*
# *Br   51 :st_base   : st_base[n_entries]/D                                   *
# *Entries :     9396 : Total  Size=   11641148 bytes  File Size  =    7453741 *
# *Baskets :       50 : Basket Size=    3551744 bytes  Compression=   1.56     *
# *............................................................................*
# *Br   52 :st_lpos   : st_lpos[n_entries]/D                                   *
# *Entries :     9396 : Total  Size=   11641148 bytes  File Size  =    5173130 *
# *Baskets :       50 : Basket Size=    3551744 bytes  Compression=   2.25     *
# *............................................................................*
# *Br   53 :st_crate  : st_crate[n_entries]/I                                  *
# *Entries :     9396 : Total  Size=    5842422 bytes  File Size  =      63488 *
# *Baskets :       53 : Basket Size=     910336 bytes  Compression=  92.00     *
# *............................................................................*
# *Br   54 :st_croc   : st_croc[n_entries]/I                                   *
# *Entries :     9396 : Total  Size=    5842365 bytes  File Size  =     372759 *
# *Baskets :       53 : Basket Size=     910336 bytes  Compression=  15.67     *
# *............................................................................*
# *Br   55 :st_chain  : st_chain[n_entries]/I                                  *
# *Entries :     9396 : Total  Size=    5842422 bytes  File Size  =     441286 *
# *Baskets :       53 : Basket Size=     910336 bytes  Compression=  13.24     *
# *............................................................................*
# *Br   56 :st_board  : st_board[n_entries]/I                                  *
# *Entries :     9396 : Total  Size=    5842422 bytes  File Size  =     690136 *
# *Baskets :       53 : Basket Size=     910336 bytes  Compression=   8.46     *
# *............................................................................*
# *Br   57 :st_pixel  : st_pixel[n_entries]/I                                  *
# *Entries :     9396 : Total  Size=    5842422 bytes  File Size  =    1675000 *
# *Baskets :       53 : Basket Size=     910336 bytes  Compression=   3.49     *
# *............................................................................*
# *Br   58 :st_pe     : st_pe[n_entries]/D                                     *
# *Entries :     9396 : Total  Size=   11641040 bytes  File Size  =    9628696 *
# *Baskets :       50 : Basket Size=    3551744 bytes  Compression=   1.21     *
# *............................................................................*
# *Br   59 :st_q      : st_q[n_entries]/D                                      *
# *Entries :     9396 : Total  Size=   11640986 bytes  File Size  =    4123559 *
# *Baskets :       50 : Basket Size=    3551744 bytes  Compression=   2.82     *
# *............................................................................*
# *Br   60 :st_s2s    : st_s2s[n_entries]/D                                    *
# *Entries :     9396 : Total  Size=   11641094 bytes  File Size  =     569632 *
# *Baskets :       50 : Basket Size=    3551744 bytes  Compression=  20.43     *
# *............................................................................*
# *Br   61 :n_clusters : n_clusters/I                                          *
# *Entries :     9396 : Total  Size=      38614 bytes  File Size  =      12620 *
# *Baskets :        7 : Basket Size=       7103 bytes  Compression=   3.02     *
# *............................................................................*
# *Br   62 :cl_subdet : cl_subdet[n_clusters]/I                                *
# *Entries :     9396 : Total  Size=    1976287 bytes  File Size  =     106760 *
# *Baskets :       23 : Basket Size=     311808 bytes  Compression=  18.50     *
# *............................................................................*
# *Br   63 :cl_module : cl_module[n_clusters]/I                                *
# *Entries :     9396 : Total  Size=    1976287 bytes  File Size  =     131079 *
# *Baskets :       23 : Basket Size=     311808 bytes  Compression=  15.07     *
# *............................................................................*
# *Br   64 :cl_plane  : cl_plane[n_clusters]/I                                 *
# *Entries :     9396 : Total  Size=    1976260 bytes  File Size  =     116802 *
# *Baskets :       23 : Basket Size=     311808 bytes  Compression=  16.91     *
# *............................................................................*
# *Br   65 :cl_tpos   : cl_tpos[n_clusters]/D                                  *
# *Entries :     9396 : Total  Size=    3911780 bytes  File Size  =    2759186 *
# *Baskets :       19 : Basket Size=    1233920 bytes  Compression=   1.42     *
# *............................................................................*
# *Br   66 :cl_lpos   : cl_lpos[n_clusters]/D                                  *
# *Entries :     9396 : Total  Size=    3911780 bytes  File Size  =    3746546 *
# *Baskets :       19 : Basket Size=    1233920 bytes  Compression=   1.04     *
# *............................................................................*
# *Br   67 :cl_pe     : cl_pe[n_clusters]/D                                    *
# *Entries :     9396 : Total  Size=    3911734 bytes  File Size  =    3706506 *
# *Baskets :       19 : Basket Size=    1233920 bytes  Compression=   1.06     *
# *............................................................................*
# *Br   68 :cl_q      : cl_q[n_clusters]/D                                     *
# *Entries :     9396 : Total  Size=    3911711 bytes  File Size  =    2780126 *
# *Baskets :       19 : Basket Size=    1233920 bytes  Compression=   1.41     *
# *............................................................................*
# *Br   69 :cl_recoE  : cl_recoE[n_clusters]/D                                 *
# *Entries :     9396 : Total  Size=    3911803 bytes  File Size  =    3733908 *
# *Baskets :       19 : Basket Size=    1233920 bytes  Compression=   1.05     *
# *............................................................................*
# *Br   70 :cl_trueE  : cl_trueE[n_clusters]/D                                 *
# *Entries :     9396 : Total  Size=    3911803 bytes  File Size  =      52462 *
# *Baskets :       19 : Basket Size=    1233920 bytes  Compression=  74.55     *
# *............................................................................*
# *Br   71 :cl_stateAx : cl_stateAx[n_clusters]/D                              *
# *Entries :     9396 : Total  Size=    3911849 bytes  File Size  =    3642390 *
# *Baskets :       19 : Basket Size=    1233920 bytes  Compression=   1.07     *
# *............................................................................*
# *Br   72 :cl_stateAy : cl_stateAy[n_clusters]/D                              *
# *Entries :     9396 : Total  Size=    3911849 bytes  File Size  =    3616989 *
# *Baskets :       19 : Basket Size=    1233920 bytes  Compression=   1.08     *
# *............................................................................*
# *Br   73 :cl_cosThetaZ : cl_cosThetaZ[n_clusters]/D                          *
# *Entries :     9396 : Total  Size=    3911895 bytes  File Size  =    3193650 *
# *Baskets :       19 : Basket Size=    1233920 bytes  Compression=   1.22     *
# *............................................................................*
# *Br   74 :cl_time   : cl_time[n_clusters]/D                                  *
# *Entries :     9396 : Total  Size=    3911780 bytes  File Size  =    3545027 *
# *Baskets :       19 : Basket Size=    1233920 bytes  Compression=   1.10     *
# *............................................................................*
# *Br   75 :cl_nstrips : cl_nstrips[n_clusters]/I                              *
# *Entries :     9396 : Total  Size=    1976314 bytes  File Size  =     257515 *
# *Baskets :       23 : Basket Size=     311808 bytes  Compression=   7.67     *
# *............................................................................*
# *Br   76 :cl_type   : cl_type[n_clusters]/I                                  *
# *Entries :     9396 : Total  Size=    1976233 bytes  File Size  =     205996 *
# *Baskets :       23 : Basket Size=     311808 bytes  Compression=   9.59     *
# *............................................................................*
# *Br   77 :cl_mightBeDead : cl_mightBeDead[n_clusters]/I                      *
# *Entries :     9396 : Total  Size=    1976422 bytes  File Size  =      38660 *
# *Baskets :       23 : Basket Size=     311808 bytes  Compression=  51.10     *
# *............................................................................*
# *Br   78 :cl_activePathLength : cl_activePathLength[n_clusters]/D            *
# *Entries :     9396 : Total  Size=    3912056 bytes  File Size  =    3476188 *
# *Baskets :       19 : Basket Size=    1234432 bytes  Compression=   1.13     *
# *............................................................................*
# *Br   79 :n_hits    : n_hits/I                                               *
# *Entries :     9396 : Total  Size=      38570 bytes  File Size  =      14298 *
# *Baskets :        7 : Basket Size=       7103 bytes  Compression=   2.66     *
# *............................................................................*
# *Br   80 :hit_crate : hit_crate[n_hits]/I                                    *
# *Entries :     9396 : Total  Size=    3239039 bytes  File Size  =      47548 *
# *Baskets :       33 : Basket Size=     509952 bytes  Compression=  68.10     *
# *............................................................................*
# *Br   81 :hit_croc  : hit_croc[n_hits]/I                                     *
# *Entries :     9396 : Total  Size=    3239002 bytes  File Size  =     354803 *
# *Baskets :       33 : Basket Size=     509952 bytes  Compression=   9.13     *
# *............................................................................*
# *Br   82 :hit_chain : hit_chain[n_hits]/I                                    *
# *Entries :     9396 : Total  Size=    3239039 bytes  File Size  =     245751 *
# *Baskets :       33 : Basket Size=     509952 bytes  Compression=  13.18     *
# *............................................................................*
# *Br   83 :hit_board : hit_board[n_hits]/I                                    *
# *Entries :     9396 : Total  Size=    3239039 bytes  File Size  =     488543 *
# *Baskets :       33 : Basket Size=     509952 bytes  Compression=   6.63     *
# *............................................................................*
# *Br   84 :hit_pixel : hit_pixel[n_hits]/I                                    *
# *Entries :     9396 : Total  Size=    3239039 bytes  File Size  =     891401 *
# *Baskets :       33 : Basket Size=     509952 bytes  Compression=   3.63     *
# *............................................................................*
# *Br   85 :hit_pe    : hit_pe[n_hits]/D                                       *
# *Entries :     9396 : Total  Size=    6436227 bytes  File Size  =    6127842 *
# *Baskets :       29 : Basket Size=    2026496 bytes  Compression=   1.05     *
# *............................................................................*
# *Br   86 :hit_rt    : hit_rt[n_hits]/D                                       *
# *Entries :     9396 : Total  Size=    6436227 bytes  File Size  =    2073254 *
# *Baskets :       29 : Basket Size=    2026496 bytes  Compression=   3.10     *
# *............................................................................*
# *Br   87 :hit_ct    : hit_ct[n_hits]/D                                       *
# *Entries :     9396 : Total  Size=    6436227 bytes  File Size  =    2073254 *
# *Baskets :       29 : Basket Size=    2026496 bytes  Compression=   3.10     *
# *............................................................................*
# *Br   88 :hit_tof   : hit_tof[n_hits]/D                                      *
# *Entries :     9396 : Total  Size=    6436260 bytes  File Size  =    4045079 *
# *Baskets :       29 : Basket Size=    2026496 bytes  Compression=   1.59     *
# *............................................................................*
# *Br   89 :hit_dtc   : hit_dtc[n_hits]/D                                      *
# *Entries :     9396 : Total  Size=    6436260 bytes  File Size  =    6062288 *
# *Baskets :       29 : Basket Size=    2026496 bytes  Compression=   1.06     *
# *............................................................................*
# *Br   90 :hit_dtm   : hit_dtm[n_hits]/D                                      *
# *Entries :     9396 : Total  Size=    6436260 bytes  File Size  =    6062254 *
# *Baskets :       29 : Basket Size=    2026496 bytes  Compression=   1.06     *
# *............................................................................*
# *Br   91 :hit_shl   : hit_shl[n_hits]/D                                      *
# *Entries :     9396 : Total  Size=    6436260 bytes  File Size  =    1073276 *
# *Baskets :       29 : Basket Size=    2026496 bytes  Compression=   6.00     *
# *............................................................................*
# *Br   92 :hit_bfl   : hit_bfl[n_hits]/D                                      *
# *Entries :     9396 : Total  Size=    6436260 bytes  File Size  =     568525 *
# *Baskets :       29 : Basket Size=    2026496 bytes  Compression=  11.32     *
# *............................................................................*
# *Br   93 :hit_cfl   : hit_cfl[n_hits]/D                                      *
# *Entries :     9396 : Total  Size=    6436260 bytes  File Size  =     349879 *
# *Baskets :       29 : Basket Size=    2026496 bytes  Compression=  18.39     *
# *............................................................................*
