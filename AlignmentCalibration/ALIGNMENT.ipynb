# %%
# REQUIRED PACKAGES
import ROOT
import math
import array
# Out:
# Welcome to JupyROOT 6.28/04

# %%
class TRIANGLE_FUNCTION:
    '''
    Input:  - u [array] : with position x.
            - par [array] : parameters [height, shift]
    Output: - Returns 0 if position after shifting is larger than strip width.
            - Returns area if position after shifting is within a strip width.
    '''
    def __call__(self, u, par):
        height, shift = par[0], par[1]
        x = u[0]
        x -= shift 
        if abs(x) > 17.0:
            return 0.0
        else: 
            return height * (17.0 - abs(x))
trianglefunction = TRIANGLE_FUNCTION()

# %%
def MyFit(h2BaseLpos, h1BaseReturn, ModTitle, i=-1):
    c2 = ROOT.TCanvas("dummy", "dummy")
    c2.cd()

    NumberLposBins = h2BaseLpos.GetYaxis().GetNbins()
    NumberRotationPoints = 6
    NumberRotationBins = NumberLposBins // NumberRotationPoints

    H1Name = ""
    F1Name = ""
    if i >= 0 and i < NumberRotationPoints:
        H1Name = '{}_rot{}'.format(ModTitle, i)
        F1Name = '{}_fit_rot{}'.format(ModTitle, i)
        minbin = i * NumberRotationBins
        maxbin = minbin + NumberRotationBins
        h1Base = h2BaseLpos.ProjectionX(H1Name, minbin, maxbin)
    else:
        H1Name = '{}_shift'.format(ModTitle)
        F1Name = '{}_fit'.format(ModTitle)
        h1Base = h2BaseLpos.ProjectionX(H1Name)

    h1Base.Scale(1.0 / NumberLposBins)
    h1Base.SetName(H1Name)
    h1Base.SetTitle(H1Name)
    h1Base.GetYaxis().SetTitle("Energy (MeV)")
    f1 = ROOT.TF1(F1Name, trianglefunction, -17.0, +17.0, 2)
    f1.SetParameter(0, 3.5)
    f1.SetParameter(1, 0.0)
    
    h1Base.Fit(F1Name, "Q", "Q")
    shift = f1.GetParameter(1)
    h1Base.Fit(F1Name, "Q", "Q", shift - 10.0, shift + 10.0)
    shift = f1.GetParameter(1)
    if h1BaseReturn != 0:
        h1BaseReturn = h1Base

    return shift

# %%
def DoAlignment():
    fptext = open("AlignmentConstants.txt", "w")

    fin = ROOT.TFile("ReadNT.root")
    moduleLposBase = fin.Get("moduleLposBase")
    
    moduleLposBase.GetYaxis().SetTitle("lpos")
    moduleLposBase.GetZaxis().SetTitle("triangle base")
    
    c1 = ROOT.TCanvas("c1", "c1")
    c1.Divide(2, 2)
    c1.Print("AlignmentBook.pdf[")

    for modbin in range(1, 241):
        module_number = moduleLposBase.GetXaxis().GetBinLowEdge(modbin)
        module = int(5 + module_number) - 5
        plane = int(2 * (module_number + 5)) % 2 + 1

        print("Doing alignment for module", module, "plane", plane)

        if plane == 1:
            c1.Clear("D")

        ModTitle = ""
        if module >= 0:
            ModTitle = "mod{:03d}pl{:1d}".format(module, plane)
        if module < 0:
            ModTitle = "modm{:1d}pl{:1d}".format(module, plane)

        moduleLposBase.GetXaxis().SetRange(modbin, modbin)

        H2Name = "{}_2D".format(ModTitle)
        h2BaseLpos = moduleLposBase.Project3D("yz")
        h2BaseLpos.SetName(H2Name)
        h2BaseLpos.SetTitle("Module {} Plane {};Base Position (mm);Longitudinal Position (mm);Average Energy (MeV)".format(module, plane))

        if h2BaseLpos.GetEntries() == 0:
            continue

        h1Base = ROOT.TH1D()

        ### SHIFT BEGINS
        # shift = -MyFit(h2BaseLpos, h1Base, ModTitle)
        i = -1
        h1BaseReturn = h1Base
        c2 = ROOT.TCanvas("dummy", "dummy")
        c2.cd()

        NumberLposBins = h2BaseLpos.GetYaxis().GetNbins()
        NumberRotationPoints = 6
        NumberRotationBins = NumberLposBins // NumberRotationPoints

        H1Name = ""
        F1Name = ""
        if i >= 0 and i < NumberRotationPoints:
            H1Name = '{}_rot{}'.format(ModTitle, i)
            F1Name = '{}_fit_rot{}'.format(ModTitle, i)
            minbin = i * NumberRotationBins
            maxbin = minbin + NumberRotationBins
            h1Base = h2BaseLpos.ProjectionX(H1Name, minbin, maxbin)
        else:
            H1Name = '{}_shift'.format(ModTitle)
            F1Name = '{}_fit'.format(ModTitle)
            h1Base = h2BaseLpos.ProjectionX(H1Name)

        h1Base.Scale(1.0 / NumberLposBins)
        h1Base.SetName(H1Name)
        h1Base.SetTitle(H1Name)
        h1Base.GetYaxis().SetTitle("Energy (MeV)")
        f1 = ROOT.TF1(F1Name, trianglefunction, -17.0, +17.0, 2)
        f1.SetParameter(0, 3.5)
        f1.SetParameter(1, 0.0)
        
        h1Base.Fit(F1Name, "Q", "Q")
        shift = f1.GetParameter(1)
        h1Base.Fit(F1Name, "Q", "Q", shift - 10.0, shift + 10.0)
        shift = f1.GetParameter(1)
        if h1BaseReturn != 0:
            h1BaseReturn = h1Base
        shift = -1*shift
        ### SHIFT ENDS
        

        ### SHIFT POINT ARRAY BEGINS
        #shift_point = array.array('d', [MyFit(h2BaseLpos, 0, ModTitle, i) for i in range(6)])
        shift_point = []
        h1BaseReturn = 0
        for i in range(6):
            
            c2 = ROOT.TCanvas("dummy", "dummy")
            c2.cd()

            NumberLposBins = h2BaseLpos.GetYaxis().GetNbins()
            NumberRotationPoints = 6
            NumberRotationBins = NumberLposBins // NumberRotationPoints

            H1Name = ""
            F1Name = ""
            if i >= 0 and i < NumberRotationPoints:
                H1Name = '{}_rot{}'.format(ModTitle, i)
                F1Name = '{}_fit_rot{}'.format(ModTitle, i)
                minbin = i * NumberRotationBins
                maxbin = minbin + NumberRotationBins
                h1Base = h2BaseLpos.ProjectionX(H1Name, minbin, maxbin)
            else:
                H1Name = '{}_shift'.format(ModTitle)
                F1Name = '{}_fit'.format(ModTitle)
                h1Base = h2BaseLpos.ProjectionX(H1Name)

            h1Base.Scale(1.0 / NumberLposBins)
            h1Base.SetName(H1Name)
            h1Base.SetTitle(H1Name)
            h1Base.GetYaxis().SetTitle("Energy (MeV)")
            f1 = ROOT.TF1(F1Name, trianglefunction, -17.0, +17.0, 2)
            f1.SetParameter(0, 3.5)
            f1.SetParameter(1, 0.0)
            
            h1Base.Fit(F1Name, "Q", "Q")
            shift = f1.GetParameter(1)
            h1Base.Fit(F1Name, "Q", "Q", shift - 10.0, shift + 10.0)
            shift = f1.GetParameter(1)
            if h1BaseReturn != 0:
                h1BaseReturn = h1Base

            shift_point.append(shift)
        ### SHIFT POINT ARRAY ENDS

        lpos_point = array.array('d', [-1200.0 + 400.0 * i + 200.0 for i in range(6)])
        shift_point = array.array('d', shift_point)

        tgrRotation = ROOT.TGraph(6, shift_point, lpos_point)
        tgrFit = ROOT.TGraph(6, lpos_point, shift_point)
        tgrFit.Fit("pol1", "Q", "Q")
        LowPoint = tgrFit.GetFunction("pol1").Eval(-1000.0)
        HighPoint = tgrFit.GetFunction("pol1").Eval(1000.0)
        rotation = 1000 * math.atan((HighPoint - LowPoint) / 2000.0)

        c1.cd(2 * (plane - 1) + 1)
        h2BaseLpos.SetMaximum(4)
        h2BaseLpos.Draw("colz")
        tgrRotation.SetMarkerStyle(ROOT.kOpenCircle)
        tgrRotation.Draw("P same")
        tline = ROOT.TLine(LowPoint, -1000.0, HighPoint, 1000.0)
        tline.SetLineWidth(3)
        tline.Draw("same")
        c1.cd(2 * (plane - 1) + 2)
        h1Base.SetMaximum(4)
        h1Base.SetTitle("Module {} Plane {};Base Position (mm);Average Energy (MeV)".format(module, plane))
        h1Base.Draw()
        ModString = "Module {} Plane {}".format(module, plane)
        ShiftString = "Shift = {:+5.3f} mm".format(shift)
        RotationString = "Rotation = {:+5.3f} mrad\n".format(rotation)
        ModLabel = ROOT.TPaveLabel(5.0, 4.00, 17.0, 3.75, ModString)
        ShiftLabel = ROOT.TPaveLabel(5.0, 3.75, 17.0, 3.50, ShiftString)
        RotationLabel = ROOT.TPaveLabel(5.0, 3.50, 17.0, 3.25, RotationString)
        ModLabel.Draw()
        ShiftLabel.Draw()
        RotationLabel.Draw()
        if plane == 2:
            c1.Print("AlignmentBook.pdf")

        c2 = ROOT.TCanvas("c2", "c2", 800, 500)
        c2.Divide(2, 1)
        c2.cd(1)
        h1Base.Draw()
        c2.cd(2)
        h2BaseLpos.Draw("colz")
        tgrRotation.Draw("P same")
        tline.Draw("same")
        if plane == 2:
            c1.Print("AlignmentBook.pdf")
        c2.Print("alignmentPlotDump/mod{:03d}pl{}.png".format(module, plane))
        del c2
        fptext.write("module: {} plane: {} shift: {} rotation: {}\n".format(module, plane, shift, rotation))
    c1.Print("AlignmentBook.pdf]")
    fptext.close()

# %%
DoAlignment()
# Out:
# Doing alignment for module -5 plane 1
# Doing alignment for module -5 plane 2
# Doing alignment for module -4 plane 1
# Doing alignment for module -4 plane 2
# Doing alignment for module -3 plane 1
# Doing alignment for module -3 plane 2
# Doing alignment for module -2 plane 1
# Doing alignment for module -2 plane 2
# Doing alignment for module -1 plane 1
# Doing alignment for module -1 plane 2
# Doing alignment for module 0 plane 1
# Doing alignment for module 0 plane 2
# Doing alignment for module 1 plane 1
# Doing alignment for module 1 plane 2
# Doing alignment for module 2 plane 1
# Doing alignment for module 2 plane 2
# Doing alignment for module 3 plane 1
# Doing alignment for module 3 plane 2
# Doing alignment for module 4 plane 1
# Doing alignment for module 4 plane 2
# Doing alignment for module 5 plane 1
# Doing alignment for module 5 plane 2
# Doing alignment for module 6 plane 1
# Doing alignment for module 6 plane 2
# Doing alignment for module 7 plane 1
# Doing alignment for module 7 plane 2
# Doing alignment for module 8 plane 1
# Doing alignment for module 8 plane 2
# Doing alignment for module 9 plane 1
# Doing alignment for module 9 plane 2
# Doing alignment for module 10 plane 1
# Doing alignment for module 10 plane 2
# Doing alignment for module 11 plane 1
# Doing alignment for module 11 plane 2
# Doing alignment for module 12 plane 1
# Doing alignment for module 12 plane 2
# Doing alignment for module 13 plane 1
# Doing alignment for module 13 plane 2
# Doing alignment for module 14 plane 1
# Doing alignment for module 14 plane 2
# Doing alignment for module 15 plane 1
# Doing alignment for module 15 plane 2
# Doing alignment for module 16 plane 1
# Doing alignment for module 16 plane 2
# Doing alignment for module 17 plane 1
# Doing alignment for module 17 plane 2
# Doing alignment for module 18 plane 1
# Doing alignment for module 18 plane 2
# Doing alignment for module 19 plane 1
# Doing alignment for module 19 plane 2
# Doing alignment for module 20 plane 1
# Doing alignment for module 20 plane 2
# Doing alignment for module 21 plane 1
# Doing alignment for module 21 plane 2
# Doing alignment for module 22 plane 1
# Doing alignment for module 22 plane 2
# Doing alignment for module 23 plane 1
# Doing alignment for module 23 plane 2
# Doing alignment for module 24 plane 1
# Doing alignment for module 24 plane 2
# Doing alignment for module 25 plane 1
# Doing alignment for module 25 plane 2
# Doing alignment for module 26 plane 1
# Doing alignment for module 26 plane 2
# Doing alignment for module 27 plane 1
# Doing alignment for module 27 plane 2
# Doing alignment for module 28 plane 1
# Doing alignment for module 28 plane 2
# Doing alignment for module 29 plane 1
# Doing alignment for module 29 plane 2
# Doing alignment for module 30 plane 1
# Doing alignment for module 30 plane 2
# Doing alignment for module 31 plane 1
# Doing alignment for module 31 plane 2
# Doing alignment for module 32 plane 1
# Doing alignment for module 32 plane 2
# Doing alignment for module 33 plane 1
# Doing alignment for module 33 plane 2
# Doing alignment for module 34 plane 1
# Doing alignment for module 34 plane 2
# Doing alignment for module 35 plane 1
# Doing alignment for module 35 plane 2
# Doing alignment for module 36 plane 1
# Doing alignment for module 36 plane 2
# Doing alignment for module 37 plane 1
# Doing alignment for module 37 plane 2
# Doing alignment for module 38 plane 1
# Doing alignment for module 38 plane 2
# Doing alignment for module 39 plane 1
# Doing alignment for module 39 plane 2
# Doing alignment for module 40 plane 1
# Doing alignment for module 40 plane 2
# Doing alignment for module 41 plane 1
# Doing alignment for module 41 plane 2
# Doing alignment for module 42 plane 1
# Doing alignment for module 42 plane 2
# Doing alignment for module 43 plane 1
# Doing alignment for module 43 plane 2
# Doing alignment for module 44 plane 1
# Doing alignment for module 44 plane 2
# Doing alignment for module 45 plane 1
# Doing alignment for module 45 plane 2
# Doing alignment for module 46 plane 1
# Doing alignment for module 46 plane 2
# Doing alignment for module 47 plane 1
# Doing alignment for module 47 plane 2
# Doing alignment for module 48 plane 1
# Doing alignment for module 48 plane 2
# Doing alignment for module 49 plane 1
# Doing alignment for module 49 plane 2
# Doing alignment for module 50 plane 1
# Doing alignment for module 50 plane 2
# Doing alignment for module 51 plane 1
# Doing alignment for module 51 plane 2
# Doing alignment for module 52 plane 1
# Doing alignment for module 52 plane 2
# Doing alignment for module 53 plane 1
# Doing alignment for module 53 plane 2
# Doing alignment for module 54 plane 1
# Doing alignment for module 54 plane 2
# Doing alignment for module 55 plane 1
# Doing alignment for module 55 plane 2
# Doing alignment for module 56 plane 1
# Doing alignment for module 56 plane 2
# Doing alignment for module 57 plane 1
# Doing alignment for module 57 plane 2
# Doing alignment for module 58 plane 1
# Doing alignment for module 58 plane 2
# Doing alignment for module 59 plane 1
# Doing alignment for module 59 plane 2
# Doing alignment for module 60 plane 1
# Doing alignment for module 60 plane 2
# Doing alignment for module 61 plane 1
# Doing alignment for module 61 plane 2
# Doing alignment for module 62 plane 1
# Doing alignment for module 62 plane 2
# Doing alignment for module 63 plane 1
# Doing alignment for module 63 plane 2
# Doing alignment for module 64 plane 1
# Doing alignment for module 64 plane 2
# Doing alignment for module 65 plane 1
# Doing alignment for module 65 plane 2
# Doing alignment for module 66 plane 1
# Doing alignment for module 66 plane 2
# Doing alignment for module 67 plane 1
# Doing alignment for module 67 plane 2
# Doing alignment for module 68 plane 1
# Doing alignment for module 68 plane 2
# Doing alignment for module 69 plane 1
# Doing alignment for module 69 plane 2
# Doing alignment for module 70 plane 1
# Doing alignment for module 70 plane 2
# Doing alignment for module 71 plane 1
# Doing alignment for module 71 plane 2
# Doing alignment for module 72 plane 1
# Doing alignment for module 72 plane 2
# Doing alignment for module 73 plane 1
# Doing alignment for module 73 plane 2
# Doing alignment for module 74 plane 1
# Doing alignment for module 74 plane 2
# Doing alignment for module 75 plane 1
# Doing alignment for module 75 plane 2
# Doing alignment for module 76 plane 1
# Doing alignment for module 76 plane 2
# Doing alignment for module 77 plane 1
# Doing alignment for module 77 plane 2
# Doing alignment for module 78 plane 1
# Doing alignment for module 78 plane 2
# Doing alignment for module 79 plane 1
# Doing alignment for module 79 plane 2
# Doing alignment for module 80 plane 1
# Doing alignment for module 80 plane 2
# Doing alignment for module 81 plane 1
# Doing alignment for module 81 plane 2
# Doing alignment for module 82 plane 1
# Doing alignment for module 82 plane 2
# Doing alignment for module 83 plane 1
# Doing alignment for module 83 plane 2
# Doing alignment for module 84 plane 1
# Doing alignment for module 84 plane 2
# Doing alignment for module 85 plane 1
# Doing alignment for module 85 plane 2
# Doing alignment for module 86 plane 1
# Doing alignment for module 86 plane 2
# Doing alignment for module 87 plane 1
# Doing alignment for module 87 plane 2
# Doing alignment for module 88 plane 1
# Doing alignment for module 88 plane 2
# Doing alignment for module 89 plane 1
# Doing alignment for module 89 plane 2
# Doing alignment for module 90 plane 1
# Doing alignment for module 90 plane 2
# Doing alignment for module 91 plane 1
# Doing alignment for module 91 plane 2
# Doing alignment for module 92 plane 1
# Doing alignment for module 92 plane 2
# Doing alignment for module 93 plane 1
# Doing alignment for module 93 plane 2
# Doing alignment for module 94 plane 1
# Doing alignment for module 94 plane 2
# Doing alignment for module 95 plane 1
# Doing alignment for module 95 plane 2
# Doing alignment for module 96 plane 1
# Doing alignment for module 96 plane 2
# Doing alignment for module 97 plane 1
# Doing alignment for module 97 plane 2
# Doing alignment for module 98 plane 1
# Doing alignment for module 98 plane 2
# Doing alignment for module 99 plane 1
# Doing alignment for module 99 plane 2
# Doing alignment for module 100 plane 1
# Doing alignment for module 100 plane 2
# Doing alignment for module 101 plane 1
# Doing alignment for module 101 plane 2
# Doing alignment for module 102 plane 1
# Doing alignment for module 102 plane 2
# Doing alignment for module 103 plane 1
# Doing alignment for module 103 plane 2
# Doing alignment for module 104 plane 1
# Doing alignment for module 104 plane 2
# Doing alignment for module 105 plane 1
# Doing alignment for module 105 plane 2
# Doing alignment for module 106 plane 1
# Doing alignment for module 106 plane 2
# Doing alignment for module 107 plane 1
# Doing alignment for module 107 plane 2
# Doing alignment for module 108 plane 1
# Doing alignment for module 108 plane 2
# Doing alignment for module 109 plane 1
# Doing alignment for module 109 plane 2
# Doing alignment for module 110 plane 1
# Doing alignment for module 110 plane 2
# Doing alignment for module 111 plane 1
# Doing alignment for module 111 plane 2
# Doing alignment for module 112 plane 1
# Doing alignment for module 112 plane 2
# Doing alignment for module 113 plane 1
# Doing alignment for module 113 plane 2
# Doing alignment for module 114 plane 1
# Doing alignment for module 114 plane 2
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1
# Info in <TCanvas::Print>: pdf file AlignmentBook.pdf has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# python ERROR: cannot open image file "alignmentPlotDump/mod001pl1.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file alignmentPlotDump/mod001pl1.png
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Info in <TCanvas::Print>: Current canvas added to pdf file AlignmentBook.pdf
# Info in <TCanvas::Print>: Current canvas added to pdf file AlignmentBook.pdf
# python ERROR: cannot open image file "alignmentPlotDump/mod001pl2.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file alignmentPlotDump/mod001pl2.png
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# python ERROR: cannot open image file "alignmentPlotDump/mod002pl1.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file alignmentPlotDump/mod002pl1.png
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Info in <TCanvas::Print>: Current canvas added to pdf file AlignmentBook.pdf
# Info in <TCanvas::Print>: Current canvas added to pdf file AlignmentBook.pdf
# python ERROR: cannot open image file "alignmentPlotDump/mod002pl2.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file alignmentPlotDump/mod002pl2.png
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# python ERROR: cannot open image file "alignmentPlotDump/mod003pl1.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file alignmentPlotDump/mod003pl1.png
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Info in <TCanvas::Print>: Current canvas added to pdf file AlignmentBook.pdf
# Info in <TCanvas::Print>: Current canvas added to pdf file AlignmentBook.pdf
# python ERROR: cannot open image file "alignmentPlotDump/mod003pl2.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file alignmentPlotDump/mod003pl2.png
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# python ERROR: cannot open image file "alignmentPlotDump/mod004pl1.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file alignmentPlotDump/mod004pl1.png
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Info in <TCanvas::Print>: Current canvas added to pdf file AlignmentBook.pdf
# Info in <TCanvas::Print>: Current canvas added to pdf file AlignmentBook.pdf
# python ERROR: cannot open image file "alignmentPlotDump/mod004pl2.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file alignmentPlotDump/mod004pl2.png
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# python ERROR: cannot open image file "alignmentPlotDump/mod005pl1.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file alignmentPlotDump/mod005pl1.png
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Info in <TCanvas::Print>: Current canvas added to pdf file AlignmentBook.pdf
# Info in <TCanvas::Print>: Current canvas added to pdf file AlignmentBook.pdf
# python ERROR: cannot open image file "alignmentPlotDump/mod005pl2.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file alignmentPlotDump/mod005pl2.png
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# python ERROR: cannot open image file "alignmentPlotDump/mod006pl1.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file alignmentPlotDump/mod006pl1.png
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Info in <TCanvas::Print>: Current canvas added to pdf file AlignmentBook.pdf
# Info in <TCanvas::Print>: Current canvas added to pdf file AlignmentBook.pdf
# python ERROR: cannot open image file "alignmentPlotDump/mod006pl2.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file alignmentPlotDump/mod006pl2.png
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# python ERROR: cannot open image file "alignmentPlotDump/mod007pl1.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file alignmentPlotDump/mod007pl1.png
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Info in <TCanvas::Print>: Current canvas added to pdf file AlignmentBook.pdf
# Info in <TCanvas::Print>: Current canvas added to pdf file AlignmentBook.pdf
# python ERROR: cannot open image file "alignmentPlotDump/mod007pl2.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file alignmentPlotDump/mod007pl2.png
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# python ERROR: cannot open image file "alignmentPlotDump/mod008pl1.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file alignmentPlotDump/mod008pl1.png
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Info in <TCanvas::Print>: Current canvas added to pdf file AlignmentBook.pdf
# Info in <TCanvas::Print>: Current canvas added to pdf file AlignmentBook.pdf
# python ERROR: cannot open image file "alignmentPlotDump/mod008pl2.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file alignmentPlotDump/mod008pl2.png
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# python ERROR: cannot open image file "alignmentPlotDump/mod009pl1.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file alignmentPlotDump/mod009pl1.png
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Info in <TCanvas::Print>: Current canvas added to pdf file AlignmentBook.pdf
# Info in <TCanvas::Print>: Current canvas added to pdf file AlignmentBook.pdf
# python ERROR: cannot open image file "alignmentPlotDump/mod009pl2.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file alignmentPlotDump/mod009pl2.png
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# python ERROR: cannot open image file "alignmentPlotDump/mod010pl1.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file alignmentPlotDump/mod010pl1.png
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Info in <TCanvas::Print>: Current canvas added to pdf file AlignmentBook.pdf
# Info in <TCanvas::Print>: Current canvas added to pdf file AlignmentBook.pdf
# python ERROR: cannot open image file "alignmentPlotDump/mod010pl2.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file alignmentPlotDump/mod010pl2.png
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# python ERROR: cannot open image file "alignmentPlotDump/mod011pl1.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file alignmentPlotDump/mod011pl1.png
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Info in <TCanvas::Print>: Current canvas added to pdf file AlignmentBook.pdf
# Info in <TCanvas::Print>: Current canvas added to pdf file AlignmentBook.pdf
# python ERROR: cannot open image file "alignmentPlotDump/mod011pl2.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file alignmentPlotDump/mod011pl2.png
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# python ERROR: cannot open image file "alignmentPlotDump/mod012pl1.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file alignmentPlotDump/mod012pl1.png
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Info in <TCanvas::Print>: Current canvas added to pdf file AlignmentBook.pdf
# Info in <TCanvas::Print>: Current canvas added to pdf file AlignmentBook.pdf
# python ERROR: cannot open image file "alignmentPlotDump/mod012pl2.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file alignmentPlotDump/mod012pl2.png
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# python ERROR: cannot open image file "alignmentPlotDump/mod013pl1.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file alignmentPlotDump/mod013pl1.png
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Info in <TCanvas::Print>: Current canvas added to pdf file AlignmentBook.pdf
# Info in <TCanvas::Print>: Current canvas added to pdf file AlignmentBook.pdf
# python ERROR: cannot open image file "alignmentPlotDump/mod013pl2.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file alignmentPlotDump/mod013pl2.png
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# python ERROR: cannot open image file "alignmentPlotDump/mod014pl1.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file alignmentPlotDump/mod014pl1.png
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Info in <TCanvas::Print>: Current canvas added to pdf file AlignmentBook.pdf
# Info in <TCanvas::Print>: Current canvas added to pdf file AlignmentBook.pdf
# python ERROR: cannot open image file "alignmentPlotDump/mod014pl2.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file alignmentPlotDump/mod014pl2.png
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# python ERROR: cannot open image file "alignmentPlotDump/mod015pl1.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file alignmentPlotDump/mod015pl1.png
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Info in <TCanvas::Print>: Current canvas added to pdf file AlignmentBook.pdf
# Info in <TCanvas::Print>: Current canvas added to pdf file AlignmentBook.pdf
# python ERROR: cannot open image file "alignmentPlotDump/mod015pl2.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file alignmentPlotDump/mod015pl2.png
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# python ERROR: cannot open image file "alignmentPlotDump/mod016pl1.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file alignmentPlotDump/mod016pl1.png
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Info in <TCanvas::Print>: Current canvas added to pdf file AlignmentBook.pdf
# Info in <TCanvas::Print>: Current canvas added to pdf file AlignmentBook.pdf
# python ERROR: cannot open image file "alignmentPlotDump/mod016pl2.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file alignmentPlotDump/mod016pl2.png
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# python ERROR: cannot open image file "alignmentPlotDump/mod017pl1.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file alignmentPlotDump/mod017pl1.png
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Info in <TCanvas::Print>: Current canvas added to pdf file AlignmentBook.pdf
# Info in <TCanvas::Print>: Current canvas added to pdf file AlignmentBook.pdf
# python ERROR: cannot open image file "alignmentPlotDump/mod017pl2.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file alignmentPlotDump/mod017pl2.png
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# python ERROR: cannot open image file "alignmentPlotDump/mod018pl1.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file alignmentPlotDump/mod018pl1.png
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Info in <TCanvas::Print>: Current canvas added to pdf file AlignmentBook.pdf
# Info in <TCanvas::Print>: Current canvas added to pdf file AlignmentBook.pdf
# python ERROR: cannot open image file "alignmentPlotDump/mod018pl2.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file alignmentPlotDump/mod018pl2.png
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# python ERROR: cannot open image file "alignmentPlotDump/mod019pl1.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file alignmentPlotDump/mod019pl1.png
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Info in <TCanvas::Print>: Current canvas added to pdf file AlignmentBook.pdf
# Info in <TCanvas::Print>: Current canvas added to pdf file AlignmentBook.pdf
# python ERROR: cannot open image file "alignmentPlotDump/mod019pl2.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file alignmentPlotDump/mod019pl2.png
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# python ERROR: cannot open image file "alignmentPlotDump/mod020pl1.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file alignmentPlotDump/mod020pl1.png
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Info in <TCanvas::Print>: Current canvas added to pdf file AlignmentBook.pdf
# Info in <TCanvas::Print>: Current canvas added to pdf file AlignmentBook.pdf
# python ERROR: cannot open image file "alignmentPlotDump/mod020pl2.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file alignmentPlotDump/mod020pl2.png
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# python ERROR: cannot open image file "alignmentPlotDump/mod021pl1.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file alignmentPlotDump/mod021pl1.png
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Info in <TCanvas::Print>: Current canvas added to pdf file AlignmentBook.pdf
# Info in <TCanvas::Print>: Current canvas added to pdf file AlignmentBook.pdf
# python ERROR: cannot open image file "alignmentPlotDump/mod021pl2.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file alignmentPlotDump/mod021pl2.png
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# python ERROR: cannot open image file "alignmentPlotDump/mod022pl1.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file alignmentPlotDump/mod022pl1.png
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Info in <TCanvas::Print>: Current canvas added to pdf file AlignmentBook.pdf
# Info in <TCanvas::Print>: Current canvas added to pdf file AlignmentBook.pdf
# python ERROR: cannot open image file "alignmentPlotDump/mod022pl2.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file alignmentPlotDump/mod022pl2.png
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# python ERROR: cannot open image file "alignmentPlotDump/mod023pl1.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file alignmentPlotDump/mod023pl1.png
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Info in <TCanvas::Print>: Current canvas added to pdf file AlignmentBook.pdf
# Info in <TCanvas::Print>: Current canvas added to pdf file AlignmentBook.pdf
# python ERROR: cannot open image file "alignmentPlotDump/mod023pl2.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file alignmentPlotDump/mod023pl2.png
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# python ERROR: cannot open image file "alignmentPlotDump/mod024pl1.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file alignmentPlotDump/mod024pl1.png
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Info in <TCanvas::Print>: Current canvas added to pdf file AlignmentBook.pdf
# Info in <TCanvas::Print>: Current canvas added to pdf file AlignmentBook.pdf
# python ERROR: cannot open image file "alignmentPlotDump/mod024pl2.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file alignmentPlotDump/mod024pl2.png
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# python ERROR: cannot open image file "alignmentPlotDump/mod025pl1.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file alignmentPlotDump/mod025pl1.png
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# ...
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Info in <TCanvas::Print>: Current canvas added to pdf file AlignmentBook.pdf
# Info in <TCanvas::Print>: Current canvas added to pdf file AlignmentBook.pdf
# python ERROR: cannot open image file "alignmentPlotDump/mod029pl2.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file alignmentPlotDump/mod029pl2.png
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# python ERROR: cannot open image file "alignmentPlotDump/mod030pl1.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file alignmentPlotDump/mod030pl1.png
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Info in <TCanvas::Print>: Current canvas added to pdf file AlignmentBook.pdf
# Info in <TCanvas::Print>: Current canvas added to pdf file AlignmentBook.pdf
# python ERROR: cannot open image file "alignmentPlotDump/mod030pl2.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file alignmentPlotDump/mod030pl2.png
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# python ERROR: cannot open image file "alignmentPlotDump/mod031pl1.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file alignmentPlotDump/mod031pl1.png
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Info in <TCanvas::Print>: Current canvas added to pdf file AlignmentBook.pdf
# Info in <TCanvas::Print>: Current canvas added to pdf file AlignmentBook.pdf
# python ERROR: cannot open image file "alignmentPlotDump/mod031pl2.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file alignmentPlotDump/mod031pl2.png
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# python ERROR: cannot open image file "alignmentPlotDump/mod032pl1.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file alignmentPlotDump/mod032pl1.png
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Info in <TCanvas::Print>: Current canvas added to pdf file AlignmentBook.pdf
# Info in <TCanvas::Print>: Current canvas added to pdf file AlignmentBook.pdf
# python ERROR: cannot open image file "alignmentPlotDump/mod032pl2.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file alignmentPlotDump/mod032pl2.png
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Info in <TCanvas::Print>: Current canvas added to pdf file AlignmentBook.pdf
# Info in <TCanvas::Print>: Current canvas added to pdf file AlignmentBook.pdf
# python ERROR: cannot open image file "alignmentPlotDump/mod033pl2.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file alignmentPlotDump/mod033pl2.png
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Info in <TCanvas::Print>: Current canvas added to pdf file AlignmentBook.pdf
# Info in <TCanvas::Print>: Current canvas added to pdf file AlignmentBook.pdf
# python ERROR: cannot open image file "alignmentPlotDump/mod034pl2.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file alignmentPlotDump/mod034pl2.png
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Info in <TCanvas::Print>: Current canvas added to pdf file AlignmentBook.pdf
# Info in <TCanvas::Print>: Current canvas added to pdf file AlignmentBook.pdf
# python ERROR: cannot open image file "alignmentPlotDump/mod035pl2.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file alignmentPlotDump/mod035pl2.png
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Info in <TCanvas::Print>: Current canvas added to pdf file AlignmentBook.pdf
# Info in <TCanvas::Print>: Current canvas added to pdf file AlignmentBook.pdf
# python ERROR: cannot open image file "alignmentPlotDump/mod036pl2.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file alignmentPlotDump/mod036pl2.png
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Info in <TCanvas::Print>: Current canvas added to pdf file AlignmentBook.pdf
# Info in <TCanvas::Print>: Current canvas added to pdf file AlignmentBook.pdf
# python ERROR: cannot open image file "alignmentPlotDump/mod037pl2.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file alignmentPlotDump/mod037pl2.png
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Info in <TCanvas::Print>: Current canvas added to pdf file AlignmentBook.pdf
# Info in <TCanvas::Print>: Current canvas added to pdf file AlignmentBook.pdf
# python ERROR: cannot open image file "alignmentPlotDump/mod038pl2.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file alignmentPlotDump/mod038pl2.png
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Info in <TCanvas::Print>: Current canvas added to pdf file AlignmentBook.pdf
# Info in <TCanvas::Print>: Current canvas added to pdf file AlignmentBook.pdf
# python ERROR: cannot open image file "alignmentPlotDump/mod039pl2.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file alignmentPlotDump/mod039pl2.png
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Info in <TCanvas::Print>: Current canvas added to pdf file AlignmentBook.pdf
# Info in <TCanvas::Print>: Current canvas added to pdf file AlignmentBook.pdf
# python ERROR: cannot open image file "alignmentPlotDump/mod040pl2.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file alignmentPlotDump/mod040pl2.png
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Info in <TCanvas::Print>: Current canvas added to pdf file AlignmentBook.pdf
# Info in <TCanvas::Print>: Current canvas added to pdf file AlignmentBook.pdf
# python ERROR: cannot open image file "alignmentPlotDump/mod041pl2.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file alignmentPlotDump/mod041pl2.png
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Info in <TCanvas::Print>: Current canvas added to pdf file AlignmentBook.pdf
# Info in <TCanvas::Print>: Current canvas added to pdf file AlignmentBook.pdf
# python ERROR: cannot open image file "alignmentPlotDump/mod042pl2.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file alignmentPlotDump/mod042pl2.png
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Info in <TCanvas::Print>: Current canvas added to pdf file AlignmentBook.pdf
# Info in <TCanvas::Print>: Current canvas added to pdf file AlignmentBook.pdf
# python ERROR: cannot open image file "alignmentPlotDump/mod043pl2.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file alignmentPlotDump/mod043pl2.png
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: dummy
# Info in <TCanvas::Print>: Current canvas added to pdf file AlignmentBook.pdf
# Info in <TCanvas::Print>: Current canvas added to pdf file AlignmentBook.pdf
# python ERROR: cannot open image file "alignmentPlotDump/mod044pl2.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file alignmentPlotDump/mod044pl2.png
# Info in <TCanvas::Print>: pdf file AlignmentBook.pdf has been closed
